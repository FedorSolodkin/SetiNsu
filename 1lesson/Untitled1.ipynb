# %%
pip install ping3
# Out:
# Collecting ping3
#   Downloading ping3-5.1.5-py3-none-any.whl.metadata (12 kB)
# Downloading ping3-5.1.5-py3-none-any.whl (15 kB)
# Installing collected packages: ping3
# Successfully installed ping3-5.1.5

# %%
from ping3 import ping
import csv

# %%
domens = ['youtube.com',"web.telegram.org","profi.ru","vk.com","sky.pro","drive.google.com","mail.google.com","yandex.ru","kwork.ru","baserow.io"]
RTT={}
RTT_par={}
RTT_max_par={}
RTT_min_par={}
lost={}
for i in domens:
    rtt_list =[]
    for j in range(4):
      a = ping(i)
      if a != None:
        rtt_list.append(a)
    RTT[i] = rtt_list
for i in domens:
  if RTT[i]:
    RTT_par[i] = sum(RTT[i]) / len(RTT[i])
  else:
    RTT_par[i] = None
for i in domens:
  lost[i]= 100*((4- len(RTT[i]))/4)
for i in domens:
  if RTT[i]:
    RTT_max_par[i] = max(RTT[i])
  else:
    RTT_max_par[i] = None
for i in domens:
  if RTT[i]:
    RTT_min_par[i] = min(RTT[i])
  else:
    RTT_min_par[i] = None
results=[]
for i in domens:
  results.append({
      'domain': i,
      'avg_rtt_sec': RTT_par[i],
      'max_rtt_sec': RTT_max_par[i],
      'loss_pct': lost[i],
      'min_rtt_sec': RTT_min_par[i]
  })
filednames=['domain','avg_rtt_sec','max_rtt_sec','loss_pct','min_rtt_sec']
with open("spisok.csv","w") as spis:
  writer = csv.DictWriter(spis,fieldnames=filednames)
  writer.writeheader()
  writer.writerows(results)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-605325798.py in <cell line: 0>()
#       8     rtt_list =[]
#       9     for j in range(4):
# ---> 10       a = ping(i)
#      11       if a != None:
#      12         rtt_list.append(a)
#
# /usr/local/lib/python3.12/dist-packages/ping3/__init__.py in wrapper(*args, **kwargs)
#      87         all_args = ", ".join((pargs, kargs)) if (pargs and kargs) else (pargs or kargs)
#      88         _debug("Function called:", "{func.__name__}({})".format(all_args, func=func))
# ---> 89         func_return = func(*args, **kwargs)
#      90         _debug("Function returned:", "{func.__name__} -> {rtrn}".format(func=func, rtrn=func_return))
#      91         return func_return
#
# /usr/local/lib/python3.12/dist-packages/ping3/__init__.py in ping(dest_addr, timeout, unit, src_addr, ttl, seq, size, interface, version)
#     450         try:
#     451             send_one_ping(sock=sock, dest_addr=dest_addr, icmp_id=icmp_id, seq=seq, size=size)
# --> 452             delay = receive_one_ping(sock=sock, icmp_id=icmp_id, seq=seq, timeout=timeout)  # in seconds
#     453         except errors.Timeout as err:
#     454             _debug(err)
#
# /usr/local/lib/python3.12/dist-packages/ping3/__init__.py in wrapper(*args, **kwargs)
#      87         all_args = ", ".join((pargs, kargs)) if (pargs and kargs) else (pargs or kargs)
#      88         _debug("Function called:", "{func.__name__}({})".format(all_args, func=func))
# ---> 89         func_return = func(*args, **kwargs)
#      90         _debug("Function returned:", "{func.__name__} -> {rtrn}".format(func=func, rtrn=func_return))
#      91         return func_return
#
# /usr/local/lib/python3.12/dist-packages/ping3/__init__.py in receive_one_ping(sock, icmp_id, seq, timeout)
#     307         _debug("Timeout left: {:.2f}s".format(timeout_left))
#     308
# --> 309         selected = select.select([sock], [], [], timeout_left)  # Wait until sock is ready to read or time is out.
#     310         if selected[0] == []:  # Timeout
#     311             raise errors.Timeout(timeout=timeout)
#
# KeyboardInterrupt:
